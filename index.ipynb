# %%
import pandas as pd

# %% [markdown]
# ## extraction

# %%
travel_dataset = pd.read_csv('https://drive.google.com/uc?id=1muwnik-uFGTKBdHmcQN5z68rD7qmdG-b')

# %%
travel_dataset.shape
# Out:
# (418, 6)

# %%
travel_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    object
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 19.7+ KB

# %%
columns = ['Employee', 'state', 'city', 'surname', 'firstname', 'Travel Start Date', 'Travel End Date', 'Actual Total Expenses', 'Purpose Of Travel'] 
final_results = travel_dataset_copy[columns].copy()

# %%
final_results.to_csv('cleaned_travels_dataset.csv')

# %%
travel_dataset_copy
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# ...

# %%
travel_dataset
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# ...

# %%
# data is an object dtype
# null values in purpose of travel
# separate state and city
# separate name
# separate date values into day, month, year

# %%
travel_dataset.drop_duplicates()
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# ...

# %% [markdown]
# ## CLEANING

# %%
travel_dataset['Travel Start Date']
# Out:
# 0           2017-05-31
# 1           2016-01-24
# 2           2018-10-04
# 3           2016-06-19
# 4           2019-11-19
#             ...
# 413    2017-11-06
# 414         2019-03-25
# 415         2017-11-06
# 416         2017-05-21
# 417         2019-08-13
# Name: Travel Start Date, Length: 418, dtype: object

# %%
travel_dataset_copy = travel_dataset.copy() # copy dataset

# %%
def remove_white_space(text):
    if type(text) == str:
        return text.strip()
    return text

# %%
travel_dataset_copy['Travel Start Date'] = travel_dataset_copy['Travel Start Date'].apply(remove_white_space) # clearing whitespaces

# %%
travel_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    object
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 19.7+ KB

# %%
travel_dataset_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    object
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 19.7+ KB

# %%
travel_dataset_copy['Travel Start Date'] = pd.to_datetime(travel_dataset_copy['Travel Start Date']) # changing travel start data from strings to date data type

# %%
travel_dataset_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 19.7+ KB

# %%
travel_dataset
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# ...

# %%
# change travel end date from string to datetime datatype
travel_dataset_copy['Travel End Date'] = travel_dataset_copy['Travel End Date'].apply(remove_white_space)

# %%
travel_dataset_copy['Travel End Date'] = pd.to_datetime(travel_dataset_copy['Travel End Date'])

# %% [markdown]
# ## null values in purpose of travel

# %%
travel_dataset_copy[travel_dataset_copy['Purpose Of Travel'].isna()]
# Out:
#              Employee     Destination Travel Start Date Travel End Date  \
# 126     Gaila Compton  OCEAN CITY, MD        2019-09-25      2019-09-27
# 274      Mark Sheelor   LAS VEGAS, NV        2017-03-06      2017-03-08
# 385  Tamara Maldonado  OCEAN CITY, MD        2017-10-19      2017-10-20
#
#      Actual Total Expenses Purpose Of Travel
# 126                 690.00               NaN
# 274                1411.34               NaN
# 385                  73.50               NaN

# %%
travel_dataset_copy['Purpose Of Travel'] = travel_dataset_copy['Purpose Of Travel'].fillna('not provided')

# %%
travel_dataset_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    datetime64[ns]
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      418 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 19.7+ KB

# %% [markdown]
# ## separate state and city

# %%
def extract_state(text):
    results = text.split(',')[1]
    return results


def extract_city(text):
    results = text.split(',')[0]
    return results

# %%
travel_dataset_copy['state'] = travel_dataset_copy['Destination'].apply(extract_state)
travel_dataset_copy['city'] = travel_dataset_copy['Destination'].apply(extract_city)

# %%
travel_dataset_copy
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel state        city
# ...

# %% [markdown]
# ## separate name

# %%
def extract_surname(text):
    results = text.split(' ')[0]
    return results

def extract_firstname(text):
    results = text.split(' ')[1]
    return results

# %%
travel_dataset_copy['surname'] = travel_dataset_copy['Employee'].apply(extract_surname)
travel_dataset_copy['firstname'] = travel_dataset_copy['Employee'].apply(extract_firstname)

# %%
travel_dataset_copy
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel state        city  surname  \
# ...

# %% [markdown]
# ## US Demography

# %% [markdown]
# 'https://drive.google.com/uc?id=1muwnik-uFGTKBdHmcQN5z68rD7qmdG-b'

# %%
import pandas as pd

# %%
url = 'https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/us-cities-demographics/exports/json?lang=en&timezone=Africa%2FLagos'
demography = pd.read_json(url)

# %%
demography.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2891 entries, 0 to 2890
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    2891 non-null   object
#  1   state                   2891 non-null   object
#  2   median_age              2891 non-null   float64
#  3   male_population         2888 non-null   float64
#  4   female_population       2888 non-null   float64
#  5   total_population        2891 non-null   int64
#  6   number_of_veterans      2878 non-null   float64
#  7   foreign_born            2878 non-null   float64
#  8   average_household_size  2875 non-null   float64
#  9   state_code              2891 non-null   object
#  10  race                    2891 non-null   object
#  11  count                   2891 non-null   int64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 271.2+ KB

# %%
demography
# Out:
#                city       state  median_age  male_population  \
# 0            Newark  New Jersey        34.6         138040.0
# 1            Peoria    Illinois        33.1          56229.0
# 2          O'Fallon    Missouri        36.0          41762.0
# 3           Hampton    Virginia        35.5          66214.0
# 4          Lakewood    Colorado        37.7          76013.0
# ...             ...         ...         ...              ...
# 2886          Tyler       Texas        33.9          50422.0
# 2887  Mission Viejo  California        44.9          48849.0
# 2888        Compton  California        30.1          49264.0
# 2889        Buffalo    New York        33.1         124537.0
# 2890        Clifton  New Jersey        38.5          41932.0
#
#       female_population  total_population  number_of_veterans  foreign_born  \
# 0              143873.0            281913              5829.0       86253.0
# 1               62432.0            118661              6634.0        7517.0
# ...

# %%
# male and female population to integer
# missing values

# %%
demography.drop_duplicates()
# Out:
#                city       state  median_age  male_population  \
# 0            Newark  New Jersey        34.6         138040.0
# 1            Peoria    Illinois        33.1          56229.0
# 2          O'Fallon    Missouri        36.0          41762.0
# 3           Hampton    Virginia        35.5          66214.0
# 4          Lakewood    Colorado        37.7          76013.0
# ...             ...         ...         ...              ...
# 2886          Tyler       Texas        33.9          50422.0
# 2887  Mission Viejo  California        44.9          48849.0
# 2888        Compton  California        30.1          49264.0
# 2889        Buffalo    New York        33.1         124537.0
# 2890        Clifton  New Jersey        38.5          41932.0
#
#       female_population  total_population  number_of_veterans  foreign_born  \
# 0              143873.0            281913              5829.0       86253.0
# 1               62432.0            118661              6634.0        7517.0
# ...

# %%
demography_copy = demography.copy()

# %% [markdown]
# ## male and female population to integer

# %%
import numpy as np

# %%
demography['male_population'] = demography['male_population'].apply(lambda x: int(x) if type(x) == np.float64 else x)

# %%
demography['male_population']
# Out:
# 0       138040.0
# 1        56229.0
# 2        41762.0
# 3        66214.0
# 4        76013.0
#           ...
# 2886     50422.0
# 2887     48849.0
# 2888     49264.0
# 2889    124537.0
# 2890     41932.0
# Name: male_population, Length: 2891, dtype: float64

# %%
demography.head()
# Out:
#        city       state  median_age  male_population  female_population  \
# 0    Newark  New Jersey        34.6         138040.0           143873.0
# 1    Peoria    Illinois        33.1          56229.0            62432.0
# 2  O'Fallon    Missouri        36.0          41762.0            43270.0
# 3   Hampton    Virginia        35.5          66214.0            70240.0
# 4  Lakewood    Colorado        37.7          76013.0            76576.0
#
#    total_population  number_of_veterans  foreign_born  average_household_size  \
# 0            281913              5829.0       86253.0                    2.73
# 1            118661              6634.0        7517.0                    2.40
# 2             85032              5783.0        3269.0                    2.77
# 3            136454             19638.0        6204.0                    2.48
# 4            152589              9988.0       14169.0                    2.29
#
#   state_code                               race  count
# ...
